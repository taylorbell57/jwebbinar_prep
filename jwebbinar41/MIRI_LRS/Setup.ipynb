# %% [markdown]
# # MIRI Data files setup for JWST Data Comparison and Fitting
#
# ## Author: Taylor Bell (ESA/AURA for STScI)
#
# This notebook downloads and installs the needed files for JWST Data Comparison and Fitting workshops (Hands-On Sessions I and II).  This notebook only needs to be run **once**.

# %%
import os
absolute_path_to_the_data_folder_on_your_machine = '/user/tbell/exoplanet_jwebbinar/miri_lrs/' # Please complete!
os.chdir(absolute_path_to_the_data_folder_on_your_machine)

# %% [markdown]
# The code cell below downloads the raw _uncal files from MAST and reorganizes it. This requires wget to be installed; the following code should then work for all operating systems.

# %%
# !bash MAST_Download.sh

# %% [markdown]
# <br/>
# Let's double-check that we have all 6 of the segments we want downloaded and stored in the 'Uncalibrated' folder.

# %%
ls Uncalibrated/
